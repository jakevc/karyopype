# %%
import karyopype.karyopype as kp

# %%
kp.plot_karyopype("hg19", "karyopype/data/regions2.bed")
# Out:
#       0          1          2
# 0  chr5    1000000    1500000
# 1  chr5   50000000   50000001
# 2  chr7  150000000  150000100
# 3  chr7   50000000   50000100
# 4  chrX   16000000   16000100
# 5  chrX  100000000  100000003
# 6  chr3   20000000   40000000
# Writing additional regions to axis.
# <module 'matplotlib.pyplot' from '/Users/vancampe/miniconda3/envs/karyopype/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
for i,r in enumerate(["karyopype/data/regions2.bed", "karyopype/data/regions.bed"]):
    print(f"{i} {r} ")
# Out:
# 0 karyopype/data/regions2.bed
# 1 karyopype/data/regions.bed
