# %%
import autoreload
# %load_ext autoreload
# %autoreload 2

# %%
import karyopype.karyopype as kp

# %%
plt, ax = kp.plot_karyopype("hg19", ["karyopype/data/regions2.bed", "karyopype/data/regions.bed"])
